# %% [markdown]
# # PYTHON STUDY GROUP GIFT: CASE STUDY PROJECT

# %% [markdown]
# # Title: Customer churn prediction

# %% [markdown]
# # Task 1: Create the variables

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False

# %% [markdown]
# # Task 2: Calculate annual subscrition value

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
print(annual_subscription)
# Out:
# 102000

# %% [markdown]
# # Task 3: Update missed payments

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1

print(missed_payment)
# Out:
# 3

# %% [markdown]
# # Task 4: Check data usage

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage

print(company_expected_usage)
# Out:
# True

# %% [markdown]
# # Task 5: Determine if customer complaints are high

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage
high_complaints = customer_care_calls > 5
print(high_complaints)
# Out:
# True

# %% [markdown]
# # Task 6: Determine if payment history is poor

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage
high_complaints = customer_care_calls > 5
customer_payment_history = missed_payment >= 3

print(customer_payment_history)
# Out:
# True

# %% [markdown]
# # Task 7: Predict churn risk

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage
high_complaints = customer_care_calls > 5
customer_payment_history = missed_payment >= 3
high_churn_risk = high_complaints and customer_payment_history

print(high_churn_risk)
# Out:
# True

# %% [markdown]
# # Task 8: Determine customer retention eligibility

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage
high_complaints = customer_care_calls > 5
customer_payment_history = missed_payment >= 3
high_churn_risk = high_complaints and customer_payment_history
customer_retention_eligibility = high_churn_risk or company_expected_usage

print(customer_retention_eligibility)
# Out:
# True

# %% [markdown]
# # Task 9: Generate a customer churn report

# %%
customer_name = "Sarah Johnson"
monthly_subscription_fee = 8500
months_with_company = 10
customer_care_calls = 6
missed_payment = 2
total_monthly_data_usage = 18
minimum_expected_usage = 20
premium_subscriber = False
annual_subscription = monthly_subscription_fee * 12
missed_payment += 1
company_expected_usage = total_monthly_data_usage < minimum_expected_usage
high_complaints = customer_care_calls > 5
customer_payment_history = missed_payment >= 3
high_churn_risk = high_complaints and customer_payment_history
customer_retention_eligibility = high_churn_risk or company_expected_usage


print("==========================================")
print("CUSTOMER CHURN PREDICTION REPORT")
print("==========================================")

print("customer_name:", customer_name)
print("monthly_subscription_fee:", monthly_subscription_fee)
print("annual_subscription:", annual_subscription)
print("months_with_company:", months_with_company)
print("customer_care_calls:", customer_care_calls)
print("missed_payment:", missed_payment)
print("total_monthly_data_usage:", total_monthly_data_usage)
print("premium_subscriber:", premium_subscriber)
print("high_complaints:", high_complaints)
print("customer_payment_history:", customer_payment_history)
print("high_churn_risk:", high_churn_risk)
print("customer_retention_eligibility:", customer_retention_eligibility)

print("===========================================")
# Out:
# ...
# CUSTOMER CHURN PREDICTION REPORT
# ...
# customer_name: Sarah Johnson
# monthly_subscription_fee: 8500
# annual_subscription: 102000
# months_with_company: 10
# customer_care_calls: 6
# missed_payment: 3
# total_monthly_data_usage: 18
# premium_subscriber: False
# high_complaints: True
# customer_payment_history: True
# high_churn_risk: True
# customer_retention_eligibility: True
# ...

# %% [markdown]
# # BONUS CHALLENGE

# %% [markdown]
# # task 1: create the variables

# %%
customer_name_1 = "David Musa"
monthly_sub_fee = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True

# %% [markdown]
# # task 2: Calculate annual subscription

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
annual_subscrption_1 = monthly_subscription_fee_1 * 12 

print(annual_subscrption_1)
# Out:
# 144000

# %% [markdown]
# # task 3: update missed payment

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
print(missed_payments_1)
# Out:
# 1

# %% [markdown]
# # task 4: Check data usage

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1

print(company_expected_usage_1)
# Out:
# False

# %% [markdown]
# # task 5: Determine if customer complaints are high

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1
high_complaints_1 = customer_care_calls_1 > 5

print(high_complaints_1)
# Out:
# False

# %% [markdown]
# # task 6: determine if payment history is poor

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1
high_complaints_1 = customer_care_calls_1 > 5
payment_history_1 = missed_payments_1 >= 3

print(payment_history_1)
# Out:
# False

# %% [markdown]
# # task 7: predict churn risk

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1
high_complaints_1 = customer_care_calls_1 > 5
payment_history_1 = missed_payments_1 >= 3
high_churn_risk = high_complaints_1 and payment_history_1 

print(high_churn_risk)
# Out:
# False

# %% [markdown]
# # task 8: Determine customer retention eligibility

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1
high_complaints_1 = customer_care_calls_1 > 5
payment_history_1 = missed_payments_1 >= 3
high_churn_risk = high_complaints_1 and payment_history_1 
customer_retention_eligibility = high_churn_risk or company_expected_usage_1

print(customer_retention_eligibility )
# Out:
# False

# %% [markdown]
# # task 9: generate a customer churn report

# %%
customer_name_1 = "David Musa"
monthly_subscription_fee_1 = 12000
months_with_company_1 = 24
customer_care_calls_1 = 2
missed_payments_1 = 0
monthly_data_usage_1 = 35
minimum_expected_usage_1 = 20
premium_subscriber_1 = True
missed_payments_1 += 1
annual_subscrption_1 = monthly_subscription_fee_1 * 12 
company_expected_usage_1 = monthly_data_usage_1 < minimum_expected_usage_1
high_complaints_1 = customer_care_calls_1 > 5
payment_history_1 = missed_payments_1 >= 3
high_churn_risk = high_complaints_1 and payment_history_1 
customer_retention_eligibility = high_churn_risk or company_expected_usage_1



print("==============================================")

print("CUSTOMER CHURN PREDICTION REPORT")

print("==============================================")

print("customer_name_1:", customer_name_1)
print("monthly_subscription_fee_1:", monthly_subscription_fee_1)
print("annual_subscrption_1:", annual_subscrption_1)
print("months_with_company_1:", months_with_company_1)
print("customer_care_calls_1:", customer_care_calls_1)
print("missed_payments_1:", missed_payments_1)
print("monthly_data_usage_1:", monthly_data_usage_1) 
print("premium_subscriber_1:", premium_subscriber_1)
print("high_complaints_1:", high_complaints_1)
print("payment_history_1:", payment_history_1)
print("high_churn_risk:", high_churn_risk)
print("customer_retention_eligibility:", customer_retention_eligibility)

print("==============================================")
# Out:
# ...
# CUSTOMER CHURN PREDICTION REPORT
# ...
# customer_name_1: David Musa
# monthly_subscription_fee_1: 12000
# annual_subscrption_1: 144000
# months_with_company_1: 24
# customer_care_calls_1: 2
# missed_payments_1: 1
# monthly_data_usage_1: 35
# premium_subscriber_1: True
# high_complaints_1: False
# payment_history_1: False
# high_churn_risk: False
# customer_retention_eligibility: False
# ...

# %% [markdown]
# # Questions

# %%
# Which customer generates more annual revenue?
# Which customer has the higher churn risk?
# Which customer should receive a retention offer?
# Which customer appears more valuable to the company?
# Based on your calculations, Which customer should the company prioritize for retention?


print("1. David Musa generate more annual revenue because his annual subscription is 144000.")
print("2. Sarah Johnson has the higher churn risk.")
print("3. Sarah Johnson should receive a retention offer.")
print("4. David Musa appears more valuable to the company because he pays more annually, has no missed payments and is a premium subscriber.")
print("5. Sarah Johnson should be prioritized for retention because she has a higher churn risk.")
# Out:
# 1. David Musa generate more annual revenue because his annual subscription is 144000.
# 2. Sarah Johnson has the higher churn risk.
# 3. Sarah Johnson should receive a retention offer.
# 4. David Musa appears more valuable to the company because he pays more annually, has no missed payments and is a premium subscriber.
# 5. Sarah Johnson should be prioritized for retention because she has a higher churn risk.
